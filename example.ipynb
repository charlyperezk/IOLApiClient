# %%
from src.iol.container import iol_client

# %%
portfolio = await iol_client.fetch_portfolio()

# %%
options = await iol_client.fetch_all_options()

# %%
with_variations_today = [option for option in options if option.variation and option.variation > 0.0]

# %%
sorted(with_variations_today, key=lambda op: op.variation, reverse=True)
# Out:
# [Option(symbol='EDNV2400AB', description='EDNV2400AB', book_entries=[], last_price=124.4, variation=107.33, open_price=91.0, high=124.4, low=91.0, previous_close=124.4, volume=0.0, trade_count=2.0, timestamp=datetime.datetime(2025, 12, 23, 15, 48, 2, 403000), market='1', currency='1', term='T1', min_lot=100.0, lot=1.0, option_type=None, strike=None, expiry=None),
#  Option(symbol='PAMC5600AB', description='PAMC5600AB', book_entries=[], last_price=560.0, variation=96.62, open_price=284.8, high=0.0, low=0.0, previous_close=560.0, volume=0.0, trade_count=0.0, timestamp=datetime.datetime(2025, 12, 23, 16, 56, 22, 927000), market='1', currency='1', term='T1', min_lot=100.0, lot=1.0, option_type=None, strike=None, expiry=None),
# ...
